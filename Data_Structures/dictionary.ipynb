# %% [markdown]
# # Dictionary

# %% [markdown]
# ### Dictionaries in python as a DS are going to store the values in a similar way line general dictionary. i.e. Key-Value format.

# %% [markdown]
# ### Syntax:
# ### {key1:value1, key2:value2, key3:value3}

# %% [markdown]
# #### NoSQL Databases --> MongoDB Databases --> These DBs consists of information in a key value format itself so again here as well dictionary knowledge matters.

# %%
dictionary = {"name":"twinlle", "phone": "425346457563", "email": "ter.te@gmail.com"}
print(dictionary["name"])
# Out:
# twinlle

# %% [markdown]
# ### Dictionary are going to be ordered but not in indexed format and it is mutual as well but we prefer to keep it as immutable.
# ### Dictionary will be having key value combinations and are ordered in a way such that only by using key name we can access the values that are their inside the dictionary and in a similar way dictionary is preffered as immutable so that for a specific key there a=must be a specific value associated.
