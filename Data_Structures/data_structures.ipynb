# %% [markdown]
# # Data Structures in Python

# %% [markdown]
# #### Data structures in Python are being used for storing that data in a structured format so that we can access the data and along with that we can perform all of the operations with these data structures that can perform in the case if databases as well like curd (Create, Read, update, delete) Operations.

# %% [markdown]
# ## Types of Data Structures:
#
# ## 1. List
# ## 2. Tuple
# ## 3. Set
# ## 4. Dictionary

# %% [markdown]
# ## The diffirent types of data structures differs on this basis that in which specific format we want to store our data.
