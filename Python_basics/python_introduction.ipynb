# %% [markdown]
# # What is Python Language?

# %% [markdown]
# ## Python is a Type of programming language which we can use for communicating with computers or technilogy.

# %% [markdown]
# # Syntax for python language

# %% [markdown]
# ## Syntax refers to the set of rules that defines the combination of symbols that are considered to be correctly structured progress in a language.

# %% [markdown]
# # Semantics of Python Language

# %% [markdown]
# ## Semantics of python language refers to the meaning or interpretation of symbols. characters and commands in a language. It is about what the code is supposed to do when it runs.

# %% [markdown]
# # Python Syntax Rules

# %% [markdown]
# ## 1. Python is case sensitive

# %%
Name="Amit"
name="Amit"
name == Name
# Out:
# True

# %%
Name="Amit"
name="amit"
name == Name
# Out:
# False

# %% [markdown]
# # Indentation in Python

# %% [markdown]
# ## in other programming language, we use {} for grouping statements.
# ## In python, we use Indentation for proper grouping of statement as the proper arragement of statements with proper spacing in the statements within a block.

# %%
age = int(input("Enter your age: "))
if age > 18:
    print("you are eligible for driving")
# Out:
# you are eligible for driving

# %%
age = int(input("Enter your age: "))
if age > 18:
print("you are eligible for driving")
# Out:
#   Cell In[7], line 3
#     print("you are eligible for driving")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
1+2+3+4+\
    5+6
# Out:
# 21

# %% [markdown]
# ## Backslash can be used to cont. the code in next line.

# %% [markdown]
# # Multiple Statements in a single line in Python

# %%
a=5;b=6;c=7
