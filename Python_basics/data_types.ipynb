# %% [markdown]
# # Data Types

# %% [markdown]
# ## Data types are classification of data that telles the complier or the interpreter that what kind of values we can store into a vairable and how much amount of memory will be consumed to store the data and the operations it can perform.

# %%
age=input("Enter the age:")
age2 = int(input("Enter age2:"))
print(type(age))
print(type(age2))
# Out:
# <class 'str'>
# <class 'int'>

# %%
age+age2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 age+age2
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Different type of data cannot be concodnated

# %% [markdown]
# ## Different type of datatypes
# 1. int
# 2. str
# 3. bool
# 4. float
