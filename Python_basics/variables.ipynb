# %% [markdown]
# # Variables

# %% [markdown]
# ## Variables are the elements in python that can be used for stroing data into it or values into it. They can be called as containers as well.
#
# ## Variables as per its name, data can vary that we are going to store into it and once we have declred a variable we can vary the value stored in it.

# %%
age = 23
Name = "Twinkle"
Height = 5.8
is_true= True

# %%
age
# Out:
# 23

# %%
Name
# Out:
# 'Twinkle'

# %% [markdown]
# # print()

# %% [markdown]
# ## print() ---> print function is being used to represent the value that we are going to pass inside it.

# %%
print("Name is :", Name)
# Out:
# Name is : Twinkle

# %% [markdown]
# ## Comment
# ## Comment is the statement in a program that we don't want the interperter to execute
# ## Interpreter --> Executed the code line by line in python
# ## Complier --> Executes the code completely

# %%
# Hi i am trying to explain commnts

# %% [markdown]
# # Variable Naming Convention

# %%
"""Variable names must be Descriptive.
    Age = 23
"""
# Out:
# 'Variable names must be Descriptive.\n    Age = 23\n'

# %%
"""They must start with a letter or underscore and con contain letter, numbers and underscores.
"""
# Out:
# 'They must start with a letter or underscore and con contain letter, numbers and underscores.\n'

# %%
name1="Twinkle"
_name="Twinkle"

# %%
"""
Variables are case sensitive.
"""
# Out:
# '\nVariables are case sensitive.\n'

# %%
name="twinkle"
Name="Twinkle"
name==Name
# Out:
# False

# %%
'''
Every type casting is Not Possible.
int --> str
str Cannot be converted into int.
'''
# Out:
# '\nEvery type casting is Not Possible.\nint --> str\nstr Cannot be converted into int.\n'

# %% [markdown]
# # input()
# ## input() can take the input from the used side and then can store that input into a variable.

# %% [markdown]
# '''
# '''
