# %% [markdown]
# # Keywords

# %% [markdown]
# ## Keywords are the reserved word which can't be used as our variable name as they are having a reserved meaning already in python.

# %%
tuple

# %%
tup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tup
#
# NameError: name 'tup' is not defined
